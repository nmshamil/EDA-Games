# %% [markdown]
# <a href="https://colab.research.google.com/github/nmshamil/EDA-Games/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install numpy
# !pip install sklearn
# !pip install seaborn
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as skl
import matplotlib.pyplot as plt
df = pd.read_csv("/shehin.csv")
df.head()
# Out:
#           Timestamp  Gender Student      Age Marital  \
# 0  12-12-2019 02:06  Female     Yes  21 - 30  Single
# 1  12-12-2019 21:41    Male     Yes  21 - 30  Single
# 2  12-12-2019 21:42  Female     Yes  21 - 30  Single
# 3  12-12-2019 21:43  Female     Yes  21 - 30  Single
# 4  12-12-2019 21:43    Male     Yes  21 - 30  Single
#
#                           Q1  Q2  Q3  Q4  Q5  Q6  Q7  total
# 0  Less than 4 hours per day   3   3   3   3   4   1     17
# 1  Less than 2 hours per day   3   3   2   2   4   4     18
# 2  4 hours and above per day   1   5   2   4   5   4     21
# 3  Less than 1 hours per day   4   4   3   3   3   1     18
# 4  Less than 1 hours per day   3   5   2   3   4   4     21

# %%
df2 = (
    df[df['total']>18]
)
df2.head()
# Out:
#              Timestamp  Gender Student      Age Marital  \
# 2     12-12-2019 21:42  Female     Yes  21 - 30  Single
# 4     12-12-2019 21:43    Male     Yes  21 - 30  Single
# 7     12-12-2019 22:38  Female     Yes  21 - 30  Single
# 8   12/13/2019 7:19:36  Female     Yes  21 - 30  Single
# 9  12/13/2019 12:10:15    Male     Yes  21 - 30  Single
#
#                           Q1  Q2  Q3  Q4  Q5  Q6  Q7  total
# 2  4 hours and above per day   1   5   2   4   5   4     21
# 4  Less than 1 hours per day   3   5   2   3   4   4     21
# 7  4 hours and above per day   4   4   3   5   5   3     24
# 8  4 hours and above per day   5   4   3   4   4   4     24
# 9  4 hours and above per day   2   5   3   2   5   2     19

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df2['gender_factor']=le.fit_transform(df2.Gender)
df2['phone_usage'] = le.fit_transform(df2.Q1)
df2.head()
# Out:
# <ipython-input-13-c263c416f516>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['gender_factor']=le.fit_transform(df2.Gender)
# <ipython-input-13-c263c416f516>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['phone_usage'] = le.fit_transform(df2.Q1)
#              Timestamp  Gender Student      Age Marital  \
# 2     12-12-2019 21:42  Female     Yes  21 - 30  Single
# 4     12-12-2019 21:43    Male     Yes  21 - 30  Single
# ...
